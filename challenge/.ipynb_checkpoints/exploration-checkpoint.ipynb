# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
from datetime import datetime

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression

import xgboost as xgb
from xgboost import plot_importance

import warnings
warnings.filterwarnings('ignore')

# %%
def plot_flights(data, title, xlabel, ylabel='Flights', rotation=90, figsize=(10, 2), color='lightblue', alpha=0.8):
    plt.figure(figsize=figsize)
    sns.set(style="darkgrid")
    sns.barplot(x=data.index, y=data.values, color=color, alpha=alpha)
    plt.title(title)
    plt.ylabel(ylabel, fontsize=12)
    plt.xlabel(xlabel, fontsize=12)
    plt.xticks(rotation=rotation)
    plt.show()
    
def plot_delay(data, title, xlabel, ylabel='Delay Rate [%]', rotation=90, figsize=(20,5), color='lightblue', alpha=0.75): 
    plt.figure(figsize=figsize)
    sns.set(style="darkgrid")
    sns.barplot(x=data.index, y=data['Tasa (%)'], alpha = alpha)
    plt.title(title)
    plt.ylabel(ylabel, fontsize=12)
    plt.xlabel(xlabel, fontsize=12)
    plt.xticks(rotation=rotation)
    plt.show()

# %%
def get_period_day(date):
    date_time = datetime.strptime(date, '%Y-%m-%d %H:%M:%S').time()
    morning_min = datetime.strptime("05:00", '%H:%M').time()
    morning_max = datetime.strptime("11:59", '%H:%M').time()
    afternoon_min = datetime.strptime("12:00", '%H:%M').time()
    afternoon_max = datetime.strptime("18:59", '%H:%M').time()
    evening_min = datetime.strptime("19:00", '%H:%M').time()
    evening_max = datetime.strptime("23:59", '%H:%M').time()
    night_min = datetime.strptime("00:00", '%H:%M').time()
    night_max = datetime.strptime("4:59", '%H:%M').time()
    
    if(date_time >= morning_min and date_time <= morning_max):
        return 'mañana'
    elif(date_time >= afternoon_min and date_time <= afternoon_max):
        return 'tarde'
    elif(
        (date_time >= evening_min and date_time <= evening_max) or
        (date_time >= night_min and date_time <= night_max)
    ):
        return 'noche'

# %%
def is_high_season(fecha):
    fecha_año = int(fecha.split('-')[0])
    fecha = datetime.strptime(fecha, '%Y-%m-%d %H:%M:%S')
    range1_min = datetime.strptime('15-Dec', '%d-%b').replace(year = fecha_año)
    range1_max = datetime.strptime('31-Dec', '%d-%b').replace(year = fecha_año)
    range2_min = datetime.strptime('1-Jan', '%d-%b').replace(year = fecha_año)
    range2_max = datetime.strptime('3-Mar', '%d-%b').replace(year = fecha_año)
    range3_min = datetime.strptime('15-Jul', '%d-%b').replace(year = fecha_año)
    range3_max = datetime.strptime('31-Jul', '%d-%b').replace(year = fecha_año)
    range4_min = datetime.strptime('11-Sep', '%d-%b').replace(year = fecha_año)
    range4_max = datetime.strptime('30-Sep', '%d-%b').replace(year = fecha_año)
    
    if ((fecha >= range1_min and fecha <= range1_max) or 
        (fecha >= range2_min and fecha <= range2_max) or 
        (fecha >= range3_min and fecha <= range3_max) or
        (fecha >= range4_min and fecha <= range4_max)):
        return 1
    else:
        return 0

# %%
def get_min_diff(data):
    fecha_o = datetime.strptime(data['Fecha-O'], '%Y-%m-%d %H:%M:%S')
    fecha_i = datetime.strptime(data['Fecha-I'], '%Y-%m-%d %H:%M:%S')
    min_diff = ((fecha_o - fecha_i).total_seconds())/60
    return min_diff

# %%
def get_rate_from_column(data, column):
    delays = {}
    for _, row in data.iterrows():
        if row['delay'] == 1:
            if row[column] not in delays:
                delays[row[column]] = 1
            else:
                delays[row[column]] += 1
    total = data[column].value_counts().to_dict()
    
    rates = {}
    for name, total in total.items():
        if name in delays:
            rates[name] = round(delays[name] / total, 2)*100
        else:
            rates[name] = 0
            
    return pd.DataFrame.from_dict(data = rates, orient = 'index', columns = ['Tasa (%)'])

# %%
def print_model_evaluation(y_true, y_preds, model_name):
    print(f"Confusion Matrix ({model_name}):")
    print(confusion_matrix(y_true, y_preds))
    print('')
    print(f"Classification Report ({model_name}):")
    print(classification_report(y_true, y_preds))

# %% [markdown]
# ## 0. Load Data

# %% [markdown]
# |Column|Description|
# |-----|-----------|
# |`Fecha-I`|Scheduled date and time of the flight.|
# |`Vlo-I`|Scheduled flight number.|
# |`Ori-I`|Programmed origin city code.|
# |`Des-I`|Programmed destination city code.|
# |`Emp-I`|Scheduled flight airline code.|
# |`Fecha-O`|Date and time of flight operation.|
# |`Vlo-O`|Flight operation number of the flight.|
# |`Ori-O`|Operation origin city code.|
# |`Des-O`|Operation destination city code.|
# |`Emp-O`|Airline code of the operated flight.|
# |`DIA`|Day of the month of flight operation.|
# |`MES`|Number of the month of operation of the flight.|
# |`AÑO`|Year of flight operation.|
# |`DIANOM`|Day of the week of flight operation.|
# |`TIPOVUELO`|Type of flight, I =International, N =National.|
# |`OPERA`|Name of the airline that operates.|
# |`SIGLAORI`|Name city of origin.|
# |`SIGLADES`|Destination city name.|

# %%
data = pd.read_csv('../data/data.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68206 entries, 0 to 68205
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha-I    68206 non-null  object
#  1   Vlo-I      68206 non-null  object
#  2   Ori-I      68206 non-null  object
#  3   Des-I      68206 non-null  object
#  4   Emp-I      68206 non-null  object
#  5   Fecha-O    68206 non-null  object
#  6   Vlo-O      68205 non-null  object
#  7   Ori-O      68206 non-null  object
#  8   Des-O      68206 non-null  object
#  9   Emp-O      68206 non-null  object
#  10  DIA        68206 non-null  int64
#  11  MES        68206 non-null  int64
#  12  AÑO        68206 non-null  int64
#  13  DIANOM     68206 non-null  object
#  14  TIPOVUELO  68206 non-null  object
#  15  OPERA      68206 non-null  object
#  16  SIGLAORI   68206 non-null  object
#  17  SIGLADES   68206 non-null  object
# dtypes: int64(3), object(15)
# memory usage: 9.4+ MB

# %% [markdown]
# ## 1. Data Analysis: First Sight

# %% [markdown]
# ### How is the date distribuited?

# %%
flights_by_airline = data['OPERA'].value_counts()
plot_flights(flights_by_airline, 'Flights by Airline', 'Airline', color='darkblue', alpha=0.9)

# %%
flights_by_day = data['DIA'].value_counts()
plot_flights(flights_by_day, 'Flights by Day', 'Day')

# %%
flights_by_month = data['MES'].value_counts()
plot_flights(flights_by_month, 'Flights by Month', 'Month')

# %%
desired_order = ['Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes', 'Sabado', 'Domingo']
flights_by_day_in_week = data['DIANOM'].value_counts().reindex(desired_order)
plot_flights(flights_by_day_in_week, 'Flights by Day in Week', 'Day in Week')

# %%
flights_by_type = data['TIPOVUELO'].value_counts()
plot_flights(flights_by_type, 'Flights by Type', 'Type', rotation=0, color='darkblue', alpha=0.9)

# %%
flight_by_destination = data['SIGLADES'].value_counts()
plot_flights(flight_by_destination, 'Flights by Destination', 'Destination')

# %% [markdown]
# ## 2. Features Generation

# %% [markdown]
# |Column|Description|
# |-----|-----------|
# |`high_season`|1 if `Date-I` is between Dec-15 and Mar-3, or Jul-15 and Jul-31, or Sep-11 and Sep-30, 0 otherwise.|
# |`min_diff`|difference in minutes between `Date-O` and `Date-I`|
# |`period_day`|morning (between 5:00 and 11:59), afternoon (between 12:00 and 18:59) and night (between 19:00 and 4:59), based on `Date-I`.|
# |`delay`|1 if `min_diff` > 15, 0 if not.|

# %% [markdown]
# ### 2.a. Period of Day

# %%
data['period_day'] = data['Fecha-I'].apply(get_period_day)

# %% [markdown]
# ### 2.b. High Season

# %%
data['high_season'] = data['Fecha-I'].apply(is_high_season)

# %% [markdown]
# ### 2.c. Difference in Minutes

# %%
data['min_diff'] = data.apply(get_min_diff, axis = 1)

# %% [markdown]
# ### 2.d. Delay

# %%
threshold_in_minutes = 15
data['delay'] = np.where(data['min_diff'] > threshold_in_minutes, 1, 0)

# %%
data.columns
# Out:
# Index(['Fecha-I', 'Vlo-I', 'Ori-I', 'Des-I', 'Emp-I', 'Fecha-O', 'Vlo-O',
#        'Ori-O', 'Des-O', 'Emp-O', 'DIA', 'MES', 'AÑO', 'DIANOM', 'TIPOVUELO',
#        'OPERA', 'SIGLAORI', 'SIGLADES', 'period_day', 'high_season',
#        'min_diff', 'delay'],
#       dtype='object')

# %% [markdown]
# ## 3. Data Analysis: Second Sight

# %% [markdown]
# ### How is the delay rate across columns?

# %%
destination_rate = get_rate_from_column(data, 'SIGLADES')
plot_delay(destination_rate, 'Delay Rate by Destination', 'Destination')

# %%
airlines_rate = get_rate_from_column(data, 'OPERA')
plot_delay(airlines_rate, 'Delay Rate by Airline', 'Airline')

# %%
month_rate = get_rate_from_column(data, 'MES')
plot_delay(month_rate, 'Delay Rate by Month', 'Month')

# %%
desired_order = ['Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes', 'Sabado', 'Domingo']
days_rate = get_rate_from_column(data, 'DIANOM').reindex(desired_order)
plot_delay(days_rate, 'Delay Rate by Day', 'Days')

# %%
high_season_rate = get_rate_from_column(data, 'high_season')
high_season_rate = high_season_rate.rename(index={0: 'no', 1: 'yes'})
plot_delay(high_season_rate, 'Delay Rate by Season', 'High Season', figsize = (5, 2), alpha=1)

# %%
flight_type_rate = get_rate_from_column(data, 'TIPOVUELO')
plot_delay(flight_type_rate, 'Delay Rate by Flight Type', 'Flight Type', figsize = (5, 2), alpha=1, rotation=0)

# %%
period_day_rate = get_rate_from_column(data, 'period_day')
plot_delay(period_day_rate, 'Delay Rate by Period of Day', 'Period', figsize = (5, 2), alpha=1, rotation=0)

# %% [markdown]
# ## 4. Training

# %% [markdown]
# ### 4.a. Data Split (Training and Validation)

# %%
training_data = shuffle(data[['OPERA', 'MES', 'TIPOVUELO', 'SIGLADES', 'DIANOM', 'delay']], random_state = 111)

# %%
features = pd.concat([
    pd.get_dummies(data['OPERA'], prefix = 'OPERA'),
    pd.get_dummies(data['TIPOVUELO'], prefix = 'TIPOVUELO'), 
    pd.get_dummies(data['MES'], prefix = 'MES')], 
    axis = 1
)
target = data['delay']

# %%
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size = 0.33, random_state = 42)

# %%
print(f"train shape: {x_train.shape} | test shape: {x_test.shape}")
# Out:
# train shape: (45698, 37) | test shape: (22508, 37)

# %%
y_train.value_counts('%')*100
# Out:
# delay
# 0    81.618452
# 1    18.381548
# Name: proportion, dtype: float64

# %%
y_test.value_counts('%')*100
# Out:
# delay
# 0    81.277768
# 1    18.722232
# Name: proportion, dtype: float64

# %% [markdown]
# ### 4.b. Model Selection

# %% [markdown]
# #### 4.b.i. XGBoost

# %%
xgb_model = xgb.XGBClassifier(random_state=1, learning_rate=0.01)
xgb_model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=1, ...)

# %%
xgboost_y_preds = xgb_model.predict(x_test)
xgboost_y_preds = [1 if y_pred > 0.5 else 0 for y_pred in xgboost_y_preds]

# %%
print_model_evaluation(y_test, xgboost_y_preds, 'XGBoost')
# Out:
# Confusion Matrix (XGBoost):
# [[18294     0]
#  [ 4214     0]]
#
# Classification Report (XGBoost):
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90     18294
#            1       0.00      0.00      0.00      4214
#
#     accuracy                           0.81     22508
#    macro avg       0.41      0.50      0.45     22508
# weighted avg       0.66      0.81      0.73     22508

# %% [markdown]
# #### 4.b.ii. Logistic Regression

# %%
reg_model = LogisticRegression()
reg_model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
reg_y_preds = reg_model.predict(x_test)

# %%
print_model_evaluation(y_test, reg_y_preds, 'Logistic Regression')
# Out:
# Confusion Matrix (Logistic Regression):
# [[18193   101]
#  [ 4086   128]]
#
# Classification Report (Logistic Regression):
#               precision    recall  f1-score   support
#
#            0       0.82      0.99      0.90     18294
#            1       0.56      0.03      0.06      4214
#
#     accuracy                           0.81     22508
#    macro avg       0.69      0.51      0.48     22508
# weighted avg       0.77      0.81      0.74     22508

# %% [markdown]
# ## 5. Data Analysis: Third Sight

# %% [markdown]
# ### Feature Importance

# %%
plt.figure(figsize = (10,5))
plot_importance(xgb_model)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
top_10_features = [
    "OPERA_Latin American Wings", 
    "MES_7",
    "MES_10",
    "OPERA_Grupo LATAM",
    "MES_12",
    "TIPOVUELO_I",
    "MES_4",
    "MES_11",
    "OPERA_Sky Airline",
    "OPERA_Copa Air"
]

# %% [markdown]
# ### Data Balance

# %%
n_y0 = len(y_train[y_train == 0])
n_y1 = len(y_train[y_train == 1])
scale = n_y0/n_y1
print(scale)
# Out:
# 4.4402380952380955

# %% [markdown]
# ## 6. Training with Improvement

# %% [markdown]
# ### 6.a. Data Split

# %%
x_train2, x_test2, y_train2, y_test2 = train_test_split(features[top_10_features], target, test_size = 0.33, random_state = 42)

# %% [markdown]
# ### 6.b. Model Selection

# %% [markdown]
# #### 6.b.i. XGBoost with Feature Importance and with Balance

# %%
xgb_model_2 = xgb.XGBClassifier(random_state=1, learning_rate=0.01, scale_pos_weight = scale)
xgb_model_2.fit(x_train2, y_train2)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=1, ...)

# %%
xgboost_y_preds_2 = xgb_model_2.predict(x_test2)

# %%
print_model_evaluation(y_test2, xgboost_y_preds_2, 'XGBoost with Feature Importance and with Balance')
# Out:
# Confusion Matrix (XGBoost with Feature Importance and with Balance):
# [[9556 8738]
#  [1313 2901]]
#
# Classification Report (XGBoost with Feature Importance and with Balance):
#               precision    recall  f1-score   support
#
#            0       0.88      0.52      0.66     18294
#            1       0.25      0.69      0.37      4214
#
#     accuracy                           0.55     22508
#    macro avg       0.56      0.61      0.51     22508
# weighted avg       0.76      0.55      0.60     22508

# %% [markdown]
# #### 6.b.ii. XGBoost with Feature Importance but without Balance

# %%
xgb_model_3 = xgb.XGBClassifier(random_state=1, learning_rate=0.01)
xgb_model_3.fit(x_train2, y_train2)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=1, ...)

# %%
xgboost_y_preds_3 = xgb_model_3.predict(x_test2)

# %%
print_model_evaluation(y_test2, xgboost_y_preds_3, 'XGBoost with Feature Importance but without Balance')
# Out:
# Confusion Matrix (XGBoost with Feature Importance but without Balance):
# [[18286     8]
#  [ 4188    26]]
#
# Classification Report (XGBoost with Feature Importance but without Balance):
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90     18294
#            1       0.76      0.01      0.01      4214
#
#     accuracy                           0.81     22508
#    macro avg       0.79      0.50      0.45     22508
# weighted avg       0.80      0.81      0.73     22508

# %% [markdown]
# #### 6.b.iii. Logistic Regression with Feature Importante and with Balance

# %%
reg_model_2 = LogisticRegression(class_weight={1: n_y0/len(y_train), 0: n_y1/len(y_train)})
reg_model_2.fit(x_train2, y_train2)
# Out:
# LogisticRegression(class_weight={0: 0.18381548426626987, 1: 0.8161845157337302})

# %%
reg_y_preds_2 = reg_model_2.predict(x_test2)

# %%
print_model_evaluation(y_test2, reg_y_preds_2, 'Logistic Regression with Feature Importante and with Balance')
# Out:
# Confusion Matrix (Logistic Regression with Feature Importante and with Balance):
# [[9487 8807]
#  [1314 2900]]
#
# Classification Report (Logistic Regression with Feature Importante and with Balance):
#               precision    recall  f1-score   support
#
#            0       0.88      0.52      0.65     18294
#            1       0.25      0.69      0.36      4214
#
#     accuracy                           0.55     22508
#    macro avg       0.56      0.60      0.51     22508
# weighted avg       0.76      0.55      0.60     22508

# %% [markdown]
# #### 6.b.iv. Logistic Regression with Feature Importante but without Balance

# %%
reg_model_3 = LogisticRegression()
reg_model_3.fit(x_train2, y_train2)
# Out:
# LogisticRegression()

# %%
reg_y_preds_3 = reg_model_3.predict(x_test2)

# %%
print_model_evaluation(y_test2, reg_y_preds_3, 'Logistic Regression with Feature Importante but without Balance')
# Out:
# Confusion Matrix (Logistic Regression with Feature Importante but without Balance):
# [[18246    48]
#  [ 4160    54]]
#
# Classification Report (Logistic Regression with Feature Importante but without Balance):
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90     18294
#            1       0.53      0.01      0.03      4214
#
#     accuracy                           0.81     22508
#    macro avg       0.67      0.51      0.46     22508
# weighted avg       0.76      0.81      0.73     22508

# %% [markdown]
# ## 7. Data Science Conclusions

# %% [markdown]
# By looking at the results of the 6 trained models, it can be determined:
# - There is no noticeable difference in results between XGBoost and LogisticRegression.
# - Does not decrease the performance of the model by reducing the features to the 10 most important.
# - Improves the model's performance when balancing classes, since it increases the recall of class "1".

# %% [markdown]
# **With this, the model to be productive must be the one that is trained with the top 10 features and class balancing, but which one?**

# %%
start_time = time.time()
reg_model_2 = LogisticRegression(class_weight={1: n_y0/len(y_train), 0: n_y1/len(y_train)})
reg_model_2.fit(x_train2, y_train2)
training_time = time.time() - start_time
print(f"LogisticRegression Training time: {training_time} seconds")
# Out:
# LogisticRegression Training time: 0.04652762413024902 seconds

# %%
start_time = time.time()
xgb_model_2 = xgb.XGBClassifier(random_state=1, learning_rate=0.01, scale_pos_weight = scale)
xgb_model_2.fit(x_train2, y_train2)
training_time = time.time() - start_time
print(f"XGBoost Training time: {training_time} seconds")
# Out:
# XGBoost Training time: 0.07649397850036621 seconds

# %%
start_time = time.time()
reg_y_preds_2 = reg_model_2.predict(x_test2)
prediction_time = time.time() - start_time
print(f"LogisticRegression Prediction time: {prediction_time} seconds")
# Out:
# LogisticRegression Prediction time: 0.0019502639770507812 seconds

# %%
start_time = time.time()
xgboost_y_preds_2 = xgb_model_2.predict(x_test2)
prediction_time = time.time() - start_time
print(f"XGBoost Prediction time: {prediction_time} seconds")
# Out:
# XGBoost Prediction time: 0.008387088775634766 seconds
